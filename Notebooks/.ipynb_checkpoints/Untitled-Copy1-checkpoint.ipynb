# %%
#testing to see data in Folium map.

import folium
import os

m = folium.Map(location=[46.8, -122.33],
                   tiles='Mapbox Bright', zoom_start=7)
m

# %%
#Congressional District 1, with points for incorporated cities, plus a grid of points added in QGIS (at 0.05 degree intervals)

m.choropleth(geo_path='WACD_01_CityGrid.geojson')
#m

# %%
import geopandas as gp
import pandas as p

geojson = 'WACD_01_CityGrid.geojson'

df = gp.read_file(geojson)

df
# Out:
#      OBJECTID           NAME CountySeat       GNIS           LastUpdate  \
# 0        64.0       Gold Bar       None  2410608.0                 None
# 1        61.0         Sultan       None  2411999.0  2007-08-31T00:00:00
# 2        62.0         Monroe       None  2411137.0  2008-02-28T00:00:00
# 3        77.0    Woodinville       None  2412298.0                 None
# 4        51.0   Lake Stevens       None  2411607.0  2008-05-31T00:00:00
# 5        21.0       Hamilton       None  2412721.0  2009-02-28T00:00:00
# 6        22.0          Lyman       None  2412927.0                 None
# 7        68.0          Index       None  2412790.0                 None
# 8       100.0      Carnation       None  2409989.0                 None
# 9        70.0        Bothell       None  2409882.0                 None
# 10      103.0         Medina       None  2411071.0                 None
# 11        3.0         Lynden       None  2410899.0  2009-02-28T00:00:00
# ...
